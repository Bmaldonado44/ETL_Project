# %%
import pandas as pd
from sqlalchemy import create_engine
import os 
import matplotlib.pyplot as plt
import csv

# %%
netflix_file = "../ETL_Project/netflix_titles.csv"
netflix_df = pd.read_csv(netflix_file)
netflix_df.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country date_added  release_year  \
# ...

# %%
sub_file = "../ETL_Project/DataNetflixSubscriber.csv"
sub_df = pd.read_csv(sub_file)
sub_df.head()
# Out:
#      imdb_id                                       title  \
# 0  tt0147800                  10 Things I Hate About You
# 1  tt7019028                        101 Dalmatian Street
# 2  tt0115433                              101 Dalmatians
# 3  tt0324941  101 Dalmatians 2: Patch's London Adventure
# 4  tt0211181                              102 Dalmatians
#
#                                                 plot    type  rated   year  \
# 0  A pretty, popular teenager can't go out on a d...   movie  PG-13   1999
# 1  This series follows the lives of Delilah and D...  series    NaN  2018–
# 2  An evil high-fashion designer plots to steal D...   movie      G   1996
# 3  Being one of 101 takes its toll on Patch, who ...   movie      G   2002
# 4  Cruella DeVil gets out of prison and goes afte...   movie      G   2000
#
#   released_at   added_at  runtime  \
# 0   31-Mar-99  12-Nov-19   97 min
# 1   25-Mar-19  28-Feb-20      NaN
# 2   27-Nov-96  12-Nov-19  103 min
# ...

# %%
#filtered dataframe from specific columns
netflix_col=["title","type","release_year"]
netflix_transformed= netflix_df[netflix_col].copy()
print(netflix_transformed)
# Out:
#                                             title     type  release_year
# 0         Norm of the North: King Sized Adventure    Movie          2019
# 1                      Jandino: Whatever it Takes    Movie          2016
# 2                              Transformers Prime  TV Show          2013
# 3                Transformers: Robots in Disguise  TV Show          2016
# 4                                    #realityhigh    Movie          2017
# ...                                           ...      ...           ...
# 6229                                 Red vs. Blue  TV Show          2015
# 6230                                        Maron  TV Show          2016
# 6231       Little Baby Bum: Nursery Rhyme Friends    Movie          2016
# 6232  A Young Doctor's Notebook and Other Stories  TV Show          2013
# 6233                                      Friends  TV Show          2003
#
# [6234 rows x 3 columns]

# %%
netflix_transformed.drop_duplicates("title", inplace=True)
netflix_transformed.set_index("title", inplace=True)

netflix_transformed.head()
# Out:
#                                             type  release_year
# title
# Norm of the North: King Sized Adventure    Movie          2019
# Jandino: Whatever it Takes                 Movie          2016
# Transformers Prime                       TV Show          2013
# Transformers: Robots in Disguise         TV Show          2016
# #realityhigh                               Movie          2017

# %%
#filtered dataframe from specific columns
disney_col=["title","type","year"]
disney_transformed= disney_df[disney_col].copy()
print(disney_transformed)
# Out:
#                                           title    type   year
# 0                    10 Things I Hate About You   movie   1999
# 1                          101 Dalmatian Street  series  2018–
# 2                                101 Dalmatians   movie   1996
# 3    101 Dalmatians 2: Patch's London Adventure   movie   2002
# 4                                102 Dalmatians   movie   2000
# ..                                          ...     ...    ...
# 987                                      Zapped   movie   2014
# 988             Zenon: Girl of the 21st Century   movie   1999
# 989                           Zenon: The Zequel   movie   2001
# 990                                   Zenon: Z3   movie   2004
# 991                                    Zootopia   movie   2016
#
# [992 rows x 3 columns]

# %%
disney_transformed.drop_duplicates("title", inplace=True)
disney_transformed.set_index("title", inplace=True)

disney_transformed.head()
# Out:
#                                               type   year
# title
# 10 Things I Hate About You                   movie   1999
# 101 Dalmatian Street                        series  2018–
# 101 Dalmatians                               movie   1996
# 101 Dalmatians 2: Patch's London Adventure   movie   2002
# 102 Dalmatians                               movie   2000
